# %%
# Importer les modules nécessaires
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder
# LabelEncoder est une classe qui permet de convertir des étiquettes catégorielles en valeurs numériques

# %%
# Lire le fichier CSV qui contient les données des clients d'une banque
data = pd.read_csv("bank_customers.csv")

# Afficher les données sous forme de tableau
data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                  39  ...                       1                      3
# 1                  44  ...                       1                      2
# 2                  36  ...                       1                      0
# 3                  34  ...                       4                      1
# 4                  21  ...                       1                      0
# ...               ...  ...                     ...                    ...
# 10122              40  ...                       2                      3
# 10123              25  ...                       2                      3
# 10124              36  ...                       3                      4
# 10125              36  ...                       3                      3
# 10126              25  ...                       2                      4
#
#        Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0           12691.0                  777          11914.0
# 1            8256.0                  864           7392.0
# 2            3418.0                    0           3418.0
# 3            3313.0                 2517            796.0
# 4            4716.0                    0           4716.0
# ...             ...                  ...              ...
# 10122        4003.0                 1851           2152.0
# 10123        4277.0                 2186           2091.0
# 10124        5409.0                    0           5409.0
# 10125        5281.0                    0           5281.0
# 10126       10388.0                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [10127 rows x 21 columns]

# %%
# Modifier l'option d'affichage de pandas pour voir toutes les colonnes des données
pd.set_option('display.max_columns', None)

# Afficher les cinq premières lignes du tableau
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# 1              44                         6                       1
# 2              36                         4                       1
# 3              34                         3                       4
# 4              21                         5                       1
#
#    Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                      3       12691.0                  777          11914.0
# 1                      2        8256.0                  864           7392.0
# 2                      0        3418.0                    0           3418.0
# 3                      1        3313.0                 2517            796.0
# 4                      0        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000

# %%
# Afficher les noms des colonnes des données
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# Afficher la forme des données, c'est-à-dire le nombre de lignes et de colonnes du tableau
data.shape
# Out:
# (10127, 21)

# %%
# Supprimer la colonne CLIENTNUM des données, car elle n'est pas utile pour l'analyse
data=data.drop(['CLIENTNUM',], axis=1)
data
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                  39                         5                       1
# 1                  44                         6                       1
# 2                  36                         4                       1
# 3                  34                         3                       4
# 4                  21                         5                       1
# ...               ...                       ...                     ...
# 10122              40                         3                       2
# 10123              25                         4                       2
# 10124              36                         5                       3
# 10125              36                         4                       3
# 10126              25                         6                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                          3       12691.0                  777
# 1                          2        8256.0                  864
# 2                          0        3418.0                    0
# 3                          1        3313.0                 2517
# 4                          0        4716.0                    0
# ...                      ...           ...                  ...
# 10122                      3        4003.0                 1851
# 10123                      3        4277.0                 2186
# 10124                      4        5409.0                    0
# 10125                      3        5281.0                    0
# 10126                      4       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [10127 rows x 20 columns]

# %%
# Afficher le nombre de valeurs manquantes par colonne dans les données
# La méthode isna() renvoie un tableau booléen indiquant si les valeurs sont manquantes ou non
# La méthode sum() calcule la somme des valeurs par colonne
data.isna().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# Afficher les types de données de chaque colonne dans les données
# La méthode dtypes renvoie une série contenant le type de données de chaque colonne
data.dtypes
# Out:
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
# Afficher les valeurs uniques de la colonne Attrition_Flag
data.Attrition_Flag.unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
# Créer une instance de la classe LabelEncoder
le = LabelEncoder()

# Transformer les valeurs catégorielles de la colonne Attrition_Flag en valeurs numériques
# La méthode fit_transform apprend les correspondances entre les catégories et les nombres, et les applique aux données
# Les valeurs numériques sont stockées dans la même colonne Attrition_Flag
data['Attrition_Flag'] = le.fit_transform(data['Attrition_Flag'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne Attrition_Flag
data.Attrition_Flag.unique()
# Out:
# array([1, 0])

# %%
# Afficher les valeurs uniques de la colonne Gender
data.Gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# Transformer les valeurs catégorielles de la colonne Gender en valeurs numériques
# La méthode fit_transform apprend les correspondances entre les catégories et les nombres, et les applique aux données
# Les valeurs numériques sont stockées dans la même colonne Gender
data['Gender'] = le.fit_transform(data['Gender'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne Gender
data.Gender.unique()
# Out:
# array([1, 0])

# %%
# Afficher les valeurs uniques de la colonne Education_Level
data.Education_Level.unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
# Transformer les valeurs catégorielles de la colonne Education_Level en valeurs numériques
# La méthode fit_transform apprend les correspondances entre les catégories et les nombres, et les applique aux données
# Les valeurs numériques sont stockées dans la même colonne Education_Level
data['Education_Level'] = le.fit_transform(data['Education_Level'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne Education_Level
data.Education_Level.unique()
# Out:
# array([3, 2, 5, 6, 0, 4, 1])

# %%
# Afficher les valeurs uniques de la colonne Marital_Status
data.Marital_Status.unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
# Transformer les valeurs catégorielles de la colonne Marital_Status en valeurs numériques
# La méthode fit_transform apprend les correspondances entre les catégories et les nombres, et les applique aux données
# Les valeurs numériques sont stockées dans la même colonne Marital_Status
data['Marital_Status'] = le.fit_transform(data['Marital_Status'])

# %%
# Afficher les nouvelle valeurs uniques de la colonne Marital_Status
data.Marital_Status.unique()
# Out:
# array([1, 2, 3, 0])

# %%
# Afficher les valeurs uniques de la colonne Income_Category
data.Income_Category.unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
# Transformer les valeurs catégorielles de la colonne Income_Category en valeurs numériques
# La méthode fit_transform apprend les correspondances entre les catégories et les nombres, et les applique aux données
# Les valeurs numériques sont stockées dans la même colonne Income_Category
data['Income_Category'] = le.fit_transform(data['Income_Category'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne Income_Category
data.Income_Category.unique()
# Out:
# array([2, 4, 3, 1, 0, 5])

# %%
# Afficher les valeurs uniques de la colonne Card_Category
data.Card_Category.unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
# Transformer les valeurs catégorielles de la colonne Card_Category en valeurs numériques
# La méthode fit_transform apprend les correspondances entre les catégories et les nombres, et les applique aux données
# Les valeurs numériques sont stockées dans la même colonne Card_Category
data['Card_Category'] = le.fit_transform(data['Card_Category'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne Card_Category
data.Card_Category.unique()
# Out:
# array([0, 1, 3, 2])

# %%
data
# Out:
#        Attrition_Flag  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0                   1            45       1                3                3
# 1                   1            49       0                5                2
# 2                   1            51       1                3                2
# 3                   1            40       0                4                3
# 4                   1            40       1                3                5
# ...               ...           ...     ...              ...              ...
# 10122               1            50       1                2                2
# 10123               0            41       1                2                6
# 10124               0            44       0                1                3
# 10125               0            30       1                2                2
# 10126               0            43       0                2                2
#
#        Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 0                   1                2              0              39
# 1                   2                4              0              44
# 2                   1                3              0              36
# 3                   3                4              0              34
# 4                   1                2              0              21
# ...               ...              ...            ...             ...
# 10122               2                1              0              40
# 10123               0                1              0              25
# 10124               1                4              0              36
# 10125               3                1              0              36
# 10126               1                4              3              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                             5                       1
# 1                             6                       1
# 2                             4                       1
# 3                             3                       4
# 4                             5                       1
# ...                         ...                     ...
# 10122                         3                       2
# 10123                         4                       2
# 10124                         5                       3
# 10125                         4                       3
# 10126                         6                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                          3       12691.0                  777
# 1                          2        8256.0                  864
# 2                          0        3418.0                    0
# 3                          1        3313.0                 2517
# 4                          0        4716.0                    0
# ...                      ...           ...                  ...
# 10122                      3        4003.0                 1851
# 10123                      3        4277.0                 2186
# 10124                      4        5409.0                    0
# 10125                      3        5281.0                    0
# 10126                      4       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [10127 rows x 20 columns]

# %%
# Afficher les types de données de chaque colonne dans les données
# La méthode dtypes renvoie une série contenant le type de données de chaque colonne
data.dtypes
# Out:
# Attrition_Flag                int32
# Customer_Age                  int64
# Gender                        int32
# Dependent_count               int64
# Education_Level               int32
# Marital_Status                int32
# Income_Category               int32
# Card_Category                 int32
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
# Créer une figure de taille 22x22 pouces
plt.figure(figsize=(22,22))

# Afficher une carte de chaleur des corrélations entre les colonnes des données
# La méthode corr() calcule la matrice de corrélation des données
# La méthode heatmap() trace une carte de chaleur à partir d'une matrice de données
# Le paramètre annot=True permet d'afficher les valeurs des corrélations sur la carte
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Séparer les données en deux variables : X et y
# X contient toutes les colonnes sauf Attrition_Flag, qui est la variable cible à prédire
# y contient uniquement la colonne Attrition_Flag, qui indique si le client a quitté la banque ou non
X = data.drop(["Attrition_Flag"],axis=1)
y = data[["Attrition_Flag"]]

# %%
# Importer la fonction train_test_split du sous-module sklearn.model_selection
from sklearn.model_selection import train_test_split

# Diviser les données en deux ensembles : un ensemble d'entraînement et un ensemble de test
# L'ensemble d'entraînement contient 70% des données, et l'ensemble de test contient 30% des données
# La fonction train_test_split renvoie quatre variables : X_train, X_test, y_train, y_test
# X_train et y_train contiennent les variables explicatives et la variable cible de l'ensemble d'entraînement
# X_test et y_test contiennent les variables explicatives et la variable cible de l'ensemble de test
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30)

# %%
# Importer la classe StandardScaler du sous-module sklearn.preprocessing
from sklearn.preprocessing import StandardScaler

# Créer une instance de la classe StandardScaler
scaler = StandardScaler()

# Appliquer la normalisation des données à l'ensemble d'entraînement
# La méthode fit_transform apprend les paramètres de la normalisation (moyenne et écart-type) et les applique aux données
# Les données normalisées sont stockées dans la variable X_train_sc
X_train_sc = scaler.fit_transform(X_train)

# Appliquer la normalisation des données à l'ensemble de test
# La méthode transform utilise les paramètres de la normalisation appris sur l'ensemble d'entraînement et les applique aux données
# Les données normalisées sont stockées dans la variable X_test_sc
X_test_sc = scaler.transform(X_test)

# %%
X_train_sc
# Out:
# array([[ 0.83590641, -0.93867142, -0.28453954, ..., -0.67866202,
#         -0.77426748, -0.99978669],
#        [-0.04692065,  1.06533551,  0.48877959, ...,  1.90284133,
#         -0.4003433 , -0.88469194],
#        [-1.81257478, -0.93867142, -1.05785868, ..., -0.93258039,
#         -0.24561605, -0.99978669],
#        ...,
#        [ 0.70978826, -0.93867142, -1.05785868, ..., -1.56737629,
#          0.16698995, -0.52142413],
#        [ 2.09708793, -0.93867142, -1.83117781, ..., -1.2711382 ,
#         -0.8129493 ,  1.30570502],
#        [-1.30810217,  1.06533551, -0.28453954, ..., -0.50938311,
#          0.50223233, -0.99978669]])

# %%
# Importer la bibliothèque keras
import keras

# Importer les classes Sequential, Dense et Activation du module keras.models
from keras.models import Sequential
from keras.layers import Dense

# %%
# Créer un modèle séquentiel vide
classifier = Sequential()

# Ajouter une couche dense avec 20 unités, une initialisation uniforme des poids, une fonction d'activation relu et une dimension d'entrée égale au nombre de colonnes de X_train
classifier.add(Dense(units = 20,kernel_initializer ="uniform",activation = "relu",input_dim = X_train.shape[1]))

# Ajouter une deuxième couche dense avec 50 unités, une initialisation uniforme des poids et une fonction d'activation relu
classifier.add(Dense(units = 50,kernel_initializer = "uniform",activation="relu"))

# Ajouter une troisième couche dense avec 50 unités, une initialisation uniforme des poids et une fonction d'activation relu
classifier.add(Dense(units = 50,kernel_initializer = "uniform",activation="relu"))

# Ajouter une quatrième couche dense avec 1 unité, une initialisation uniforme des poids et une fonction d'activation sigmoid
# Cette couche représente la sortie du modèle, qui est une probabilité entre 0 et 1
classifier.add(Dense(units = 1,kernel_initializer = "uniform",activation = "sigmoid"))

# %%
#afficher le nombres de colonnes et de ligne du dataset
data.shape
# Out:
# (10127, 20)

# %%
# Compiler le modèle en utilisant l'optimiseur adam, la fonction de coût binary_crossentropy et la métrique accuracy
classifier.compile(optimizer = "adam",loss ="binary_crossentropy",metrics=["accuracy"])

# %%
# Entraîner le modèle sur l'ensemble d'entraînement normalisé, avec une taille de lot de 10, un nombre d'époques de 100 et une validation croisée de 20%
# La méthode fit renvoie un objet historique qui contient les valeurs de la fonction de coût et de la métrique à chaque époque
model = classifier.fit(X_train_sc,y_train,batch_size=10,epochs = 100,validation_split=0.2)
# Out:
# Epoch 1/100
# 567/567 [==============================] - 9s 13ms/step - loss: 0.3162 - accuracy: 0.8677 - val_loss: 0.2340 - val_accuracy: 0.9196
# Epoch 2/100
# 567/567 [==============================] - 7s 12ms/step - loss: 0.2114 - accuracy: 0.9219 - val_loss: 0.1924 - val_accuracy: 0.9302
# Epoch 3/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.1914 - accuracy: 0.9270 - val_loss: 0.1803 - val_accuracy: 0.9330
# Epoch 4/100
# 567/567 [==============================] - 10s 17ms/step - loss: 0.1867 - accuracy: 0.9275 - val_loss: 0.1812 - val_accuracy: 0.9309
# Epoch 5/100
# 567/567 [==============================] - 7s 13ms/step - loss: 0.1783 - accuracy: 0.9300 - val_loss: 0.1821 - val_accuracy: 0.9302
# Epoch 6/100
# 567/567 [==============================] - 8s 13ms/step - loss: 0.1796 - accuracy: 0.9293 - val_loss: 0.1808 - val_accuracy: 0.9309
# Epoch 7/100
# 567/567 [==============================] - 8s 14ms/step - loss: 0.1749 - accuracy: 0.9326 - val_loss: 0.1821 - val_accuracy: 0.9295
# Epoch 8/100
# 567/567 [==============================] - 9s 15ms/step - loss: 0.1726 - accuracy: 0.9349 - val_loss: 0.1781 - val_accuracy: 0.9337
# Epoch 9/100
# 567/567 [==============================] - 14s 25ms/step - loss: 0.1734 - accuracy: 0.9326 - val_loss: 0.1752 - val_accuracy: 0.9323
# Epoch 10/100
# 567/567 [==============================] - 5s 10ms/step - loss: 0.1596 - accuracy: 0.9369 - val_loss: 0.1775 - val_accuracy: 0.9330
# Epoch 18/100
# 567/567 [==============================] - 8s 14ms/step - loss: 0.1576 - accuracy: 0.9383 - val_loss: 0.1780 - val_accuracy: 0.9323
# Epoch 19/100
# 567/567 [==============================] - 6s 11ms/step - loss: 0.1552 - accuracy: 0.9402 - val_loss: 0.1862 - val_accuracy: 0.9267
# Epoch 20/100
# 567/567 [==============================] - 7s 13ms/step - loss: 0.1544 - accuracy: 0.9379 - val_loss: 0.1854 - val_accuracy: 0.9260
# Epoch 21/100
# 567/567 [==============================] - 7s 13ms/step - loss: 0.1524 - accuracy: 0.9400 - val_loss: 0.1876 - val_accuracy: 0.9288
# Epoch 22/100
# 567/567 [==============================] - 7s 12ms/step - loss: 0.1511 - accuracy: 0.9390 - val_loss: 0.1871 - val_accuracy: 0.9231
# Epoch 23/100
# 567/567 [==============================] - 19s 33ms/step - loss: 0.1504 - accuracy: 0.9388 - val_loss: 0.1876 - val_accuracy: 0.9295
# Epoch 24/100
# 567/567 [==============================] - 35s 61ms/step - loss: 0.1481 - accuracy: 0.9422 - val_loss: 0.1848 - val_accuracy: 0.9309
# Epoch 25/100
# 567/567 [==============================] - 10s 18ms/step - loss: 0.1474 - accuracy: 0.9404 - val_loss: 0.1806 - val_accuracy: 0.9309
# Epoch 26/100
# 567/567 [==============================] - 7s 12ms/step - loss: 0.1448 - accuracy: 0.9400 - val_loss: 0.1881 - val_accuracy: 0.9309
# Epoch 27/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.1434 - accuracy: 0.9414 - val_loss: 0.1867 - val_accuracy: 0.9302
# Epoch 28/100
# 567/567 [==============================] - 4s 8ms/step - loss: 0.1414 - accuracy: 0.9409 - val_loss: 0.1907 - val_accuracy: 0.9295
# Epoch 29/100
# 567/567 [==============================] - 5s 8ms/step - loss: 0.1392 - accuracy: 0.9437 - val_loss: 0.1882 - val_accuracy: 0.9316
# Epoch 30/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.1379 - accuracy: 0.9444 - val_loss: 0.1756 - val_accuracy: 0.9372
# Epoch 31/100
# 567/567 [==============================] - 4s 6ms/step - loss: 0.1366 - accuracy: 0.9448 - val_loss: 0.1835 - val_accuracy: 0.9302
# Epoch 32/100
# 567/567 [==============================] - 6s 11ms/step - loss: 0.1352 - accuracy: 0.9436 - val_loss: 0.1820 - val_accuracy: 0.9330
# Epoch 33/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.1355 - accuracy: 0.9459 - val_loss: 0.1836 - val_accuracy: 0.9323
# Epoch 34/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.1313 - accuracy: 0.9478 - val_loss: 0.1747 - val_accuracy: 0.9379
# Epoch 35/100
# 567/567 [==============================] - 6s 10ms/step - loss: 0.1289 - accuracy: 0.9471 - val_loss: 0.1845 - val_accuracy: 0.9267
# Epoch 36/100
# 567/567 [==============================] - 6s 11ms/step - loss: 0.1268 - accuracy: 0.9467 - val_loss: 0.1854 - val_accuracy: 0.9337
# Epoch 37/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.1263 - accuracy: 0.9499 - val_loss: 0.1812 - val_accuracy: 0.9372
# Epoch 38/100
# 567/567 [==============================] - 10s 18ms/step - loss: 0.1223 - accuracy: 0.9517 - val_loss: 0.1823 - val_accuracy: 0.9351
# Epoch 39/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.1219 - accuracy: 0.9504 - val_loss: 0.1891 - val_accuracy: 0.9358
# Epoch 40/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.1247 - accuracy: 0.9485 - val_loss: 0.1821 - val_accuracy: 0.9372
# Epoch 41/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.1174 - accuracy: 0.9534 - val_loss: 0.1808 - val_accuracy: 0.9351
# Epoch 42/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1168 - accuracy: 0.9522 - val_loss: 0.1871 - val_accuracy: 0.9316
# Epoch 43/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1145 - accuracy: 0.9517 - val_loss: 0.1915 - val_accuracy: 0.9316
# Epoch 44/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1145 - accuracy: 0.9540 - val_loss: 0.1839 - val_accuracy: 0.9365
# Epoch 45/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1164 - accuracy: 0.9527 - val_loss: 0.1765 - val_accuracy: 0.9372
# Epoch 46/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1112 - accuracy: 0.9538 - val_loss: 0.1941 - val_accuracy: 0.9323
# Epoch 47/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1102 - accuracy: 0.9549 - val_loss: 0.1932 - val_accuracy: 0.9337
# Epoch 48/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1067 - accuracy: 0.9563 - val_loss: 0.1780 - val_accuracy: 0.9337
# Epoch 49/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1047 - accuracy: 0.9591 - val_loss: 0.1896 - val_accuracy: 0.9379
# Epoch 50/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1037 - accuracy: 0.9580 - val_loss: 0.1829 - val_accuracy: 0.9358
# Epoch 51/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1032 - accuracy: 0.9561 - val_loss: 0.1873 - val_accuracy: 0.9344
# Epoch 52/100
# 567/567 [==============================] - 4s 6ms/step - loss: 0.1041 - accuracy: 0.9568 - val_loss: 0.1806 - val_accuracy: 0.9351
# Epoch 53/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.1001 - accuracy: 0.9566 - val_loss: 0.2035 - val_accuracy: 0.9302
# Epoch 54/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0997 - accuracy: 0.9603 - val_loss: 0.1905 - val_accuracy: 0.9330
# Epoch 55/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0963 - accuracy: 0.9601 - val_loss: 0.2175 - val_accuracy: 0.9267
# Epoch 56/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0988 - accuracy: 0.9607 - val_loss: 0.2038 - val_accuracy: 0.9323
# Epoch 57/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0941 - accuracy: 0.9601 - val_loss: 0.1970 - val_accuracy: 0.9365
# Epoch 58/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0933 - accuracy: 0.9605 - val_loss: 0.1900 - val_accuracy: 0.9365
# Epoch 59/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0891 - accuracy: 0.9631 - val_loss: 0.1868 - val_accuracy: 0.9358
# Epoch 60/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0882 - accuracy: 0.9640 - val_loss: 0.1930 - val_accuracy: 0.9210
# Epoch 61/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0874 - accuracy: 0.9624 - val_loss: 0.2091 - val_accuracy: 0.9351
# Epoch 62/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0853 - accuracy: 0.9663 - val_loss: 0.2233 - val_accuracy: 0.9330
# Epoch 63/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0864 - accuracy: 0.9644 - val_loss: 0.1928 - val_accuracy: 0.9302
# Epoch 64/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.0838 - accuracy: 0.9660 - val_loss: 0.1895 - val_accuracy: 0.9316
# Epoch 65/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.0823 - accuracy: 0.9653 - val_loss: 0.2100 - val_accuracy: 0.9323
# Epoch 66/100
# 567/567 [==============================] - 4s 8ms/step - loss: 0.0776 - accuracy: 0.9679 - val_loss: 0.2087 - val_accuracy: 0.9316
# Epoch 67/100
# 567/567 [==============================] - 6s 10ms/step - loss: 0.0758 - accuracy: 0.9698 - val_loss: 0.2493 - val_accuracy: 0.9337
# Epoch 68/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0861 - accuracy: 0.9656 - val_loss: 0.2037 - val_accuracy: 0.9267
# Epoch 69/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0742 - accuracy: 0.9702 - val_loss: 0.2173 - val_accuracy: 0.9288
# Epoch 70/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0715 - accuracy: 0.9713 - val_loss: 0.2407 - val_accuracy: 0.9210
# Epoch 71/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0788 - accuracy: 0.9668 - val_loss: 0.2338 - val_accuracy: 0.9295
# Epoch 72/100
# 567/567 [==============================] - 4s 6ms/step - loss: 0.0759 - accuracy: 0.9697 - val_loss: 0.2397 - val_accuracy: 0.9302
# Epoch 73/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0699 - accuracy: 0.9737 - val_loss: 0.2392 - val_accuracy: 0.9267
# Epoch 74/100
# 567/567 [==============================] - 4s 6ms/step - loss: 0.0719 - accuracy: 0.9704 - val_loss: 0.2485 - val_accuracy: 0.9260
# Epoch 75/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0696 - accuracy: 0.9714 - val_loss: 0.2519 - val_accuracy: 0.9288
# Epoch 76/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0639 - accuracy: 0.9721 - val_loss: 0.2460 - val_accuracy: 0.9316
# Epoch 77/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0622 - accuracy: 0.9751 - val_loss: 0.2757 - val_accuracy: 0.9302
# Epoch 78/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.0762 - accuracy: 0.9679 - val_loss: 0.2400 - val_accuracy: 0.9344
# Epoch 79/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.0724 - accuracy: 0.9714 - val_loss: 0.2427 - val_accuracy: 0.9309
# Epoch 80/100
# 567/567 [==============================] - 5s 8ms/step - loss: 0.0610 - accuracy: 0.9746 - val_loss: 0.2388 - val_accuracy: 0.9288
# Epoch 81/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0575 - accuracy: 0.9778 - val_loss: 0.2591 - val_accuracy: 0.9344
# Epoch 82/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0628 - accuracy: 0.9746 - val_loss: 0.2952 - val_accuracy: 0.9260
# Epoch 83/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0641 - accuracy: 0.9744 - val_loss: 0.2922 - val_accuracy: 0.9309
# Epoch 84/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0572 - accuracy: 0.9767 - val_loss: 0.2726 - val_accuracy: 0.9344
# Epoch 85/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0581 - accuracy: 0.9776 - val_loss: 0.2787 - val_accuracy: 0.9323
# Epoch 86/100
# 567/567 [==============================] - 5s 8ms/step - loss: 0.0640 - accuracy: 0.9750 - val_loss: 0.2530 - val_accuracy: 0.9309
# Epoch 87/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0538 - accuracy: 0.9781 - val_loss: 0.2613 - val_accuracy: 0.9224
# Epoch 88/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0541 - accuracy: 0.9776 - val_loss: 0.3133 - val_accuracy: 0.9302
# Epoch 89/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0622 - accuracy: 0.9764 - val_loss: 0.2990 - val_accuracy: 0.9168
# Epoch 90/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0556 - accuracy: 0.9799 - val_loss: 0.2704 - val_accuracy: 0.9323
# Epoch 91/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0510 - accuracy: 0.9802 - val_loss: 0.2917 - val_accuracy: 0.9260
# Epoch 92/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0594 - accuracy: 0.9778 - val_loss: 0.2781 - val_accuracy: 0.9295
# Epoch 93/100
# 567/567 [==============================] - 3s 6ms/step - loss: 0.0499 - accuracy: 0.9813 - val_loss: 0.2941 - val_accuracy: 0.9330
# Epoch 94/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0469 - accuracy: 0.9822 - val_loss: 0.2987 - val_accuracy: 0.9323
# Epoch 95/100
# 567/567 [==============================] - 6s 10ms/step - loss: 0.0472 - accuracy: 0.9811 - val_loss: 0.2740 - val_accuracy: 0.9245
# Epoch 96/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0456 - accuracy: 0.9817 - val_loss: 0.3106 - val_accuracy: 0.9316
# Epoch 97/100
# 567/567 [==============================] - 6s 10ms/step - loss: 0.0465 - accuracy: 0.9811 - val_loss: 0.3285 - val_accuracy: 0.9323
# Epoch 98/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.0440 - accuracy: 0.9825 - val_loss: 0.3153 - val_accuracy: 0.9281
# Epoch 99/100
# 567/567 [==============================] - 5s 9ms/step - loss: 0.0482 - accuracy: 0.9804 - val_loss: 0.3184 - val_accuracy: 0.9260
# Epoch 100/100
# 567/567 [==============================] - 4s 7ms/step - loss: 0.0600 - accuracy: 0.9772 - val_loss: 0.3263 - val_accuracy: 0.9316

# %%
# Importer le module matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
# Afficher la courbe de la fonction de coût du modèle pendant l'entraînement
# La fonction de coût mesure l'erreur entre les prédictions du modèle et les valeurs réelles
# La méthode plot trace une courbe à partir d'une liste de valeurs
# Le paramètre label permet de nommer la courbe pour la légende
plt.plot(model.history["loss"], label="training_loss")

# Afficher la courbe de la fonction de coût du modèle pendant la validation
# La validation permet d'évaluer le modèle sur un sous-ensemble des données d'entraînement qui n'est pas utilisé pour l'apprentissage
# La fonction de coût de validation mesure l'erreur entre les prédictions du modèle et les valeurs réelles sur le sous-ensemble de validation
plt.plot(model.history["val_loss"], label="validation_loss")

# Ajouter un titre au graphique
plt.title("Model loss during training")

# Afficher la légende des courbes
plt.legend()

# %%
# Afficher la courbe de la métrique du modèle pendant l'entraînement
# La métrique mesure la performance du modèle selon un critère choisi
# Ici, la métrique est l'accuracy, qui correspond au taux de bonnes prédictions
plt.plot(model.history["accuracy"], label="accuracy")

# Afficher la courbe de la métrique du modèle pendant la validation
# La métrique de validation mesure la performance du modèle sur le sous-ensemble de validation selon le même critère
plt.plot(model.history["val_accuracy"], label="validation_accuracy")

# Ajouter un titre au graphique
plt.title("Model accuracy during training")

# Afficher la légende des courbes
plt.legend()

# %%
# Prédire les classes des données de test à partir du modèle
# La méthode predict renvoie une probabilité entre 0 et 1 pour chaque donnée de test
# Pour obtenir une classe binaire (0 ou 1), on utilise un seuil de 0.5
# Si la probabilité est supérieure à 0.5, la classe prédite est 1, sinon elle est 0
y_pred = classifier.predict(X_test)
y_pred = (y_pred >0.5)
# Out:
# 95/95 [==============================] - 1s 8ms/step

# %%
# Importer la fonction confusion_matrix du sous-module sklearn.metrics
from sklearn.metrics import confusion_matrix

# Calculer la matrice de confusion entre les classes réelles et les classes prédites
# La matrice de confusion est un tableau qui indique le nombre de bonnes et de mauvaises prédictions pour chaque classe
# La diagonale de la matrice contient le nombre de bonnes prédictions, et les autres cases contiennent le nombre de mauvaises prédictions
cm = confusion_matrix(y_test,y_pred)

# Importer le module seaborn
import seaborn as sns

# Afficher la matrice de confusion sous forme de carte de chaleur
# La méthode heatmap trace une carte de chaleur à partir d'une matrice de données
# Le paramètre annot=True permet d'afficher les valeurs de la matrice sur la carte
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
