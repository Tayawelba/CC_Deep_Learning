# %%
# Importer les modules nécessaires
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder
# LabelEncoder est une classe qui permet de convertir des étiquettes catégorielles en valeurs numériques

# %%
# Lire le fichier CSV qui contient les données des clients d'une banque
data = pd.read_csv("insurance.csv")
# Afficher les données sous forme de tableau
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#afficher le nombres de colonnes et de ligne du dataset
data.shape
# Out:
# (1338, 7)

# %%
#types des donnees
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#verifications des cases vides
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Afficher les valeurs uniques de la colonne sex
data.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
le = LabelEncoder()
data['sex'] = le.fit_transform(data['sex'])

# %%
#verifiactions des outlayer
sns.boxplot(x = "charges",data=data)
# Out:
# <Axes: xlabel='charges'>

# %%
# Afficher les nouvelles valeurs uniques de la colonne sex
data.sex.unique()
# Out:
# array([0, 1])

# %%
# Afficher les valeurs uniques de la colonne smoker
data.smoker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
le2 = LabelEncoder()
data['smoker'] = le2.fit_transform(data['smoker'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne smoker
data.smoker.unique()
# Out:
# array([1, 0])

# %%
# Afficher les valeurs uniques de la colonne region
data.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
le3 = LabelEncoder()
data['region'] = le3.fit_transform(data['region'])

# %%
# Afficher les nouvelles valeurs uniques de la colonne region
data.region.unique()
# Out:
# array([3, 2, 1, 0])

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
#types des donnees
data.dtypes
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %%
# Créer une figure de taille 7x7 pouces
plt.figure(figsize=(7,7))
# Afficher une carte de chaleur des corrélations entre les colonnes des données
# La méthode corr() calcule la matrice de corrélation des données
# La méthode heatmap() trace une carte de chaleur à partir d'une matrice de données
# Le paramètre annot=True permet d'afficher les valeurs des corrélations sur la carte
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Afficher les noms des colonnes des données
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# Séparer les données en deux variables : X et y
# X contient toutes les colonnes sauf charges, qui est la variable cible à prédire
# y contient uniquement la colonne charges, qui indique si le client a quitté la banque ou non
X = data.drop(["charges"],axis=1)
y = data[["charges"]]

# %%
# Importer la fonction train_test_split du sous-module sklearn.model_selection
from sklearn.model_selection import train_test_split

# Diviser les données en deux ensembles : un ensemble d'entraînement et un ensemble de test
# L'ensemble d'entraînement contient 75% des données, et l'ensemble de test contient 25% des données
# La fonction train_test_split renvoie quatre variables : X_train, X_test, y_train, y_test
# X_train et y_train contiennent les variables explicatives et la variable cible de l'ensemble d'entraînement
# X_test et y_test contiennent les variables explicatives et la variable cible de l'ensemble de test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25)

# %%
# Importer la classe MinMaxScaler du sous-module sklearn.preprocessing
from sklearn.preprocessing import MinMaxScaler

# Créer une instance de la classe MinMaxScaler
scaler = MinMaxScaler()

# Appliquer la normalisation des données à l'ensemble d'entraînement
# La méthode fit_transform apprend les paramètres de la normalisation (minimum et maximum) et les applique aux données
# La normalisation consiste à transformer les valeurs des données dans l'intervalle [0,1] selon la formule : (x - min) / (max - min)
# Les données normalisées sont stockées dans la variable X_train_sc
X_train_sc = scaler.fit_transform(X_train)

# %%
# Appliquer la normalisation des données à l'ensemble de test
# La méthode fit_transform apprend les paramètres de la normalisation (minimum et maximum) et les applique aux données
# La normalisation consiste à transformer les valeurs des données dans l'intervalle [0,1] selon la formule : (x - min) / (max - min)
# Les données normalisées sont stockées dans la variable X_test_sc
X_test_sc = scaler.fit_transform(X_test)
X_test_sc
# Out:
# array([[0.80434783, 1.        , 0.67047555, 0.6       , 0.        ,
#         0.33333333],
#        [0.34782609, 1.        , 0.55268022, 0.        , 0.        ,
#         0.66666667],
#        [0.5       , 0.        , 0.35439422, 0.2       , 0.        ,
#         0.33333333],
#        ...,
#        [0.39130435, 0.        , 0.0702403 , 0.        , 0.        ,
#         0.        ],
#        [0.5       , 0.        , 0.48512855, 0.2       , 0.        ,
#         1.        ],
#        [0.08695652, 1.        , 0.53789279, 0.        , 0.        ,
#         0.66666667]])

# %%
# Appliquer la normalisation des données à la variable cible y_train
# La méthode fit_transform apprend les paramètres de la normalisation (minimum et maximum) et les applique aux données
# La normalisation consiste à transformer les valeurs des données dans l'intervalle [0,1] selon la formule : (x - min) / (max - min)
# Les données normalisées sont stockées dans la variable y_train_sc
y_train_sc = scaler.fit_transform(y_train)
y_train_sc
# Out:
# array([[0.01033795],
#        [0.60846685],
#        [0.6179655 ],
#        ...,
#        [0.17253792],
#        [0.16817379],
#        [0.61852713]])

# %% [markdown]
# ## Contruction de ANN

# %%
# Importer la bibliothèque keras
import keras

# Importer les classes Sequential, Dense et Activation du module keras.models
from keras.models import Sequential
from keras.layers import Dense

# %%
# Créer un modèle séquentiel vide
model_ann = Sequential()

# Ajouter une couche dense avec 7 unités, une initialisation uniforme des poids, une fonction d'activation relu et une dimension d'entrée égale au nombre de colonnes de X_train
model_ann.add(Dense(units = 7,kernel_initializer ="uniform",activation = "relu",input_dim = X_train.shape[1]))

# Ajouter une deuxième couche dense avec 10 unités, une initialisation uniforme des poids et une fonction d'activation relu
model_ann.add(Dense(units = 10,kernel_initializer = "uniform",activation="relu"))

# Ajouter une troisième couche dense avec 10 unités, une initialisation uniforme des poids et une fonction d'activation relu
model_ann.add(Dense(units = 10,kernel_initializer = "uniform",activation="relu"))

# Ajouter une quatrième couche dense avec 1 unité, une initialisation uniforme des poids et une fonction d'activation linéaire
# Cette couche représente la sortie du modèle, qui est une valeur continue
model_ann.add(Dense(units = 1,kernel_initializer = "uniform",activation = "linear"))

# Afficher le résumé du modèle, qui indique le nombre de paramètres et de couches du modèle
model_ann.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 7)                 49
#
#  dense_9 (Dense)             (None, 10)                80
#
#  dense_10 (Dense)            (None, 10)                110
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 250
# Trainable params: 250
# Non-trainable params: 0
# _________________________________________________________________

# %%
data.shape
# Out:
# (1338, 7)

# %%
# Compiler le modèle en utilisant l'optimiseur Adam, la fonction de coût mean_squared_error et la métrique accuracy
model_ann.compile(optimizer = 'Adam', loss = 'mean_squared_error', metrics = ['accuracy'])

# %%
# Entraîner le modèle sur l'ensemble d'entraînement normalisé, avec un nombre d'époques de 250, une taille de lot de 32 et une validation croisée de 20%
# La méthode fit renvoie un objet historique qui contient les valeurs de la fonction de coût et de la métrique à chaque époque
model = model_ann.fit(X_train_sc, y_train_sc, epochs = 250, batch_size = 32, validation_split=0.2)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 3s 29ms/step - loss: 0.0704 - accuracy: 0.0012 - val_loss: 0.0530 - val_accuracy: 0.0000e+00
# Epoch 2/250
# 26/26 [==============================] - 0s 19ms/step - loss: 0.0539 - accuracy: 0.0012 - val_loss: 0.0373 - val_accuracy: 0.0000e+00
# Epoch 3/250
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0369 - accuracy: 0.0012 - val_loss: 0.0328 - val_accuracy: 0.0000e+00
# Epoch 4/250
# 26/26 [==============================] - 0s 19ms/step - loss: 0.0348 - accuracy: 0.0012 - val_loss: 0.0306 - val_accuracy: 0.0000e+00
# Epoch 5/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0322 - accuracy: 0.0012 - val_loss: 0.0287 - val_accuracy: 0.0000e+00
# Epoch 6/250
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0296 - accuracy: 0.0012 - val_loss: 0.0255 - val_accuracy: 0.0000e+00
# Epoch 7/250
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0253 - accuracy: 0.0012 - val_loss: 0.0203 - val_accuracy: 0.0000e+00
# Epoch 8/250
# 26/26 [==============================] - 1s 24ms/step - loss: 0.0193 - accuracy: 0.0012 - val_loss: 0.0136 - val_accuracy: 0.0000e+00
# Epoch 9/250
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0128 - accuracy: 0.0025 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 10/250
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0105 - accuracy: 0.0025 - val_loss: 0.0078 - val_accuracy: 0.0000e+00
# Epoch 11/250
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0102 - accuracy: 0.0025 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 12/250
# 26/26 [==============================] - 1s 55ms/step - loss: 0.0102 - accuracy: 0.0025 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 13/250
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0102 - accuracy: 0.0025 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 14/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0100 - accuracy: 0.0025 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 15/250
# 26/26 [==============================] - 1s 23ms/step - loss: 0.0099 - accuracy: 0.0025 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 16/250
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0099 - accuracy: 0.0025 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 17/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0100 - accuracy: 0.0025 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 18/250
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0099 - accuracy: 0.0025 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 19/250
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0098 - accuracy: 0.0025 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 20/250
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0097 - accuracy: 0.0025 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 21/250
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0098 - accuracy: 0.0025 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 22/250
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0098 - accuracy: 0.0025 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 23/250
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0098 - accuracy: 0.0025 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 24/250
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0097 - accuracy: 0.0025 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 25/250
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0097 - accuracy: 0.0025 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 26/250
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0098 - accuracy: 0.0025 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 27/250
# 26/26 [==============================] - 0s 19ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 28/250
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0099 - accuracy: 0.0025 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 29/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 30/250
# 26/26 [==============================] - 1s 20ms/step - loss: 0.0097 - accuracy: 0.0025 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 31/250
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 32/250
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0099 - accuracy: 0.0025 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 33/250
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 0.0025 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 34/250
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0097 - accuracy: 0.0025 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 35/250
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 36/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 37/250
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 0.0025 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 38/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0095 - accuracy: 0.0025 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 39/250
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0095 - accuracy: 0.0025 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 40/250
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0095 - accuracy: 0.0025 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 41/250
# 26/26 [==============================] - 1s 32ms/step - loss: 0.0094 - accuracy: 0.0025 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 42/250
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 43/250
# 26/26 [==============================] - 1s 27ms/step - loss: 0.0096 - accuracy: 0.0025 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 44/250
# 26/26 [==============================] - 1s 25ms/step - loss: 0.0093 - accuracy: 0.0025 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 45/250
# 13/26 [==============>...............] - ETA: 0s - loss: 0.0108 - accuracy: 0.0048

# %%
model.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Importer le module matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.plot(model.history["loss"])
plt.plot(model.history["val_loss"])
plt.title("Model loss during training")
plt.legend(["training_loss","validation_loss"])

# %%
plt.plot(model.history["accuracy"])
plt.plot(model.history["val_accuracy"])
plt.title("Model loss during training")
plt.legend(["accuracy","validation_loss"])

# %%
# Prédire les valeurs de la variable cible y_test à partir du modèle entraîné
# La méthode predict renvoie les valeurs normalisées entre 0 et 1
y_predict = model_ann.predict(X_test_sc)
y_predict
# Out:
# 11/11 [==============================] - 0s 12ms/step
# array([[0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883],
#        [0.19637883]], dtype=float32)

# %%
# Inverser la normalisation des données pour obtenir les valeurs originales
# La méthode inverse_transform utilise les paramètres de la normalisation appris sur l'ensemble d'entraînement et les inverse sur les données
# Les valeurs originales sont stockées dans la variable y_predict_orig
y_predict_orig = scaler2.inverse_transform(y_predict)
y_predict_orig
# Out:
# array([[13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724],
#        [13424.724]], dtype=float32)

# %%
# Convertir la variable y_test en un tableau numpy
# La variable y_test est une série pandas qui contient les valeurs originales de la variable cible
y_test_orig = np.array(y_test)
y_test_orig
# Out:
# array([[30063.58055],
#        [ 3935.1799 ],
#        [ 7153.5539 ],
#        [11253.421  ],
#        [ 5846.9176 ],
#        [ 1984.4533 ],
#        [ 8059.6791 ],
#        [44400.4064 ],
#        [ 3736.4647 ],
#        [35160.13457],
#        [ 4340.4409 ],
#        [21348.706  ],
#        [ 2203.73595],
#        [40273.6455 ],
#        [17560.37975],
#        [ 3062.50825],
#        [41661.602  ],
#        [ 5934.3798 ],
#        [ 5138.2567 ],
#        [20277.80751],
#        [14043.4767 ],
#        [ 2020.177  ],
#        [21344.8467 ],
#        [14426.07385],
#        [ 6555.07035],
#        [ 1137.011  ],
#        [13217.0945 ],
#        [ 9058.7303 ],
#        [ 9625.92   ],
#        [ 2205.9808 ],
#        [ 8798.593  ],
#        [ 8603.8234 ],
#        [17361.7661 ],
#        [24106.91255],
#        [13012.20865],
#        [ 5124.1887 ],
#        [27218.43725],
#        [11033.6617 ],
#        [ 2416.955  ],
#        [ 1639.5631 ],
#        [ 2138.0707 ],
#        [ 5425.02335],
#        [34617.84065],
#        [ 4266.1658 ],
#        [20878.78443],
#        [47496.49445],
#        [ 8520.026  ],
#        [ 1534.3045 ],
#        [25333.33284],
#        [ 8023.13545],
#        [11090.7178 ],
#        [ 2250.8352 ],
#        [ 1759.338  ],
#        [ 3558.62025],
#        [12333.828  ],
#        [15019.76005],
#        [ 7740.337  ],
#        [ 1725.5523 ],
#        [15161.5344 ],
#        [11187.6567 ],
#        [11015.1747 ],
#        [ 5699.8375 ],
#        [ 3537.703  ],
#        [ 3227.1211 ],
#        [ 2897.3235 ],
#        [ 2257.47525],
#        [37742.5757 ],
#        [ 9644.2525 ],
#        [ 7133.9025 ],
#        [13770.0979 ],
#        [38511.6283 ],
#        [10461.9794 ],
#        [ 6985.50695],
#        [41034.2214 ],
#        [ 4687.797  ],
#        [13616.3586 ],
#        [18328.2381 ],
#        [45710.20785],
#        [19442.3535 ],
#        [ 1149.3959 ],
#        [ 8283.6807 ],
#        [ 5116.5004 ],
#        [14451.83515],
#        [23244.7902 ],
#        [18259.216  ],
#        [ 8556.907  ],
#        [10226.2842 ],
#        [ 3292.52985],
#        [ 7789.635  ],
#        [12949.1554 ],
#        [18033.9679 ],
#        [38344.566  ],
#        [ 9283.562  ],
#        [11165.41765],
#        [27037.9141 ],
#        [ 8116.26885],
#        [ 9866.30485],
#        [41097.16175],
#        [12913.9924 ],
#        [39047.285  ],
#        [26018.95052],
#        [11737.84884],
#        [26125.67477],
#        [36085.219  ],
#        [12629.1656 ],
#        [13747.87235],
#        [15612.19335],
#        [ 2527.81865],
#        [ 8026.6666 ],
#        [21771.3423 ],
#        [ 8606.2174 ],
#        [ 4415.1588 ],
#        [12950.0712 ],
#        [ 1842.519  ],
#        [ 5383.536  ],
#        [19350.3689 ],
#        [39774.2763 ],
#        [13129.60345],
#        [ 5385.3379 ],
#        [11879.10405],
#        [11658.37915],
#        [20745.9891 ],
#        [ 6128.79745],
#        [ 1253.936  ],
#        [ 9704.66805],
#        [ 4296.2712 ],
#        [19798.05455],
#        [10370.91255],
#        [14283.4594 ],
#        [42211.1382 ],
#        [ 1621.8827 ],
#        [37829.7242 ],
#        [19040.876  ],
#        [11455.28   ],
#        [ 3393.35635],
#        [ 8765.249  ],
#        [ 3757.8448 ],
#        [ 7228.21565],
#        [17496.306  ],
#        [10977.2063 ],
#        [44585.45587],
#        [ 4795.6568 ],
#        [23045.56616],
#        [ 6186.127  ],
#        [ 9957.7216 ],
#        [ 1629.8335 ],
#        [37465.34375],
#        [34779.615  ],
#        [ 9869.8102 ],
#        [12622.1795 ],
#        [ 2842.76075],
#        [24535.69855],
#        [12124.9924 ],
#        [ 2643.2685 ],
#        [ 3077.0955 ],
#        [ 6664.68595],
#        [ 9101.798  ],
#        [ 7986.47525],
#        [14001.1338 ],
#        [ 1526.312  ],
#        [14988.432  ],
#        [ 1986.9334 ],
#        [ 6112.35295],
#        [13974.45555],
#        [ 3392.9768 ],
#        [ 1917.3184 ],
#        [52590.82939],
#        [ 8835.26495],
#        [11842.442  ],
#        [ 7623.518  ],
#        [11674.13   ],
#        [11362.755  ],
#        [37165.1638 ],
#        [ 8988.15875],
#        [10601.412  ],
#        [22462.04375],
#        [ 7160.3303 ],
#        [ 3704.3545 ],
#        [ 2254.7967 ],
#        [ 6435.6237 ],
#        [ 7441.501  ],
#        [ 6653.7886 ],
#        [10264.4421 ],
#        [ 3875.7341 ],
#        [12032.326  ],
#        [ 6373.55735],
#        [11073.176  ],
#        [10422.91665],
#        [10141.1362 ],
#        [ 8457.818  ],
#        [37133.8982 ],
#        [ 1837.237  ],
#        [42124.5153 ],
#        [16796.41194],
#        [27117.99378],
#        [18972.495  ],
#        [ 5972.378  ],
#        [40720.55105],
#        [14119.62   ],
#        [34672.1472 ],
#        [ 3987.926  ],
#        [ 1615.7667 ],
#        [ 7209.4918 ],
#        [ 4837.5823 ],
#        [11520.09985],
#        [ 4441.21315],
#        [15518.18025],
#        [ 2904.088  ],
#        [23306.547  ],
#        [ 5630.45785],
#        [ 9724.53   ],
#        [13937.6665 ],
#        [21223.6758 ],
#        [20781.48892],
#        [ 9549.5651 ],
#        [45702.02235],
#        [43813.8661 ],
#        [26926.5144 ],
#        [17352.6803 ],
#        [21232.18226],
#        [ 4877.98105],
#        [ 3857.75925],
#        [ 3172.018  ],
#        [10942.13205],
#        [10797.3362 ],
#        [ 2304.0022 ],
#        [ 5920.1041 ],
#        [27322.73386],
#        [40419.0191 ],
#        [12741.16745],
#        [23568.272  ],
#        [14394.39815],
#        [46599.1084 ],
#        [ 4134.08245],
#        [ 4718.20355],
#        [ 2055.3249 ],
#        [12044.342  ],
#        [39983.42595],
#        [28950.4692 ],
#        [ 6238.298  ],
#        [ 3279.86855],
#        [ 8442.667  ],
#        [ 2150.469  ],
#        [ 4032.2407 ],
#        [32734.1863 ],
#        [48824.45   ],
#        [46889.2612 ],
#        [ 2130.6759 ],
#        [ 2154.361  ],
#        [ 1708.0014 ],
#        [ 8083.9198 ],
#        [10791.96   ],
#        [10795.93733],
#        [ 1708.92575],
#        [ 5375.038  ],
#        [12523.6048 ],
#        [ 4762.329  ],
#        [ 4686.3887 ],
#        [ 2020.5523 ],
#        [20420.60465],
#        [ 5910.944  ],
#        [ 9414.92   ],
#        [13844.506  ],
#        [ 5976.8311 ],
#        [17468.9839 ],
#        [ 9991.03765],
#        [ 5397.6167 ],
#        [ 2709.1119 ],
#        [ 8516.829  ],
#        [ 2166.732  ],
#        [11944.59435],
#        [ 9722.7695 ],
#        [ 9872.701  ],
#        [41949.2441 ],
#        [ 7742.1098 ],
#        [22144.032  ],
#        [ 2201.0971 ],
#        [ 9910.35985],
#        [14590.63205],
#        [ 8891.1395 ],
#        [28868.6639 ],
#        [19719.6947 ],
#        [ 5257.50795],
#        [ 3021.80915],
#        [12268.63225],
#        [ 2026.9741 ],
#        [ 2867.1196 ],
#        [ 2902.9065 ],
#        [11085.5868 ],
#        [ 9361.3268 ],
#        [ 4536.259  ],
#        [13887.204  ],
#        [17626.23951],
#        [ 4357.04365],
#        [ 8125.7845 ],
#        [29141.3603 ],
#        [48885.13561],
#        [ 1622.1885 ],
#        [26392.26029],
#        [ 6196.448  ],
#        [13112.6048 ],
#        [13457.9608 ],
#        [ 5325.651  ],
#        [16884.924  ],
#        [ 1631.8212 ],
#        [23807.2406 ],
#        [ 7537.1639 ],
#        [ 2731.9122 ],
#        [ 7371.772  ],
#        [ 2404.7338 ],
#        [ 6796.86325],
#        [ 1880.487  ],
#        [ 8823.98575],
#        [23065.4207 ],
#        [36837.467  ],
#        [ 9800.8882 ],
#        [39727.614  ],
#        [37270.1512 ],
#        [ 9850.432  ],
#        [ 2102.2647 ],
#        [ 5979.731  ],
#        [ 9541.69555],
#        [ 4399.731  ],
#        [ 1826.843  ],
#        [24059.68019],
#        [ 9500.57305],
#        [13880.949  ],
#        [21984.47061],
#        [21472.4788 ],
#        [ 7147.4728 ],
#        [ 9566.9909 ],
#        [ 2137.6536 ],
#        [ 5458.04645],
#        [ 6775.961  ],
#        [ 1674.6323 ]])

# %%
# Normaliser la variable y_test avec les mêmes paramètres que l'ensemble d'entraînement
# La méthode transform utilise les paramètres de la normalisation appris sur l'ensemble d'entraînement et les applique aux données
# Les valeurs normalisées sont stockées dans la variable y_test_sc
y_test_sc = scaler2.transform(y_test)
y_test_sc
# Out:
# array([[4.61969267e-01],
#        [4.49061601e-02],
#        [9.62780400e-02],
#        [1.61720366e-01],
#        [7.54214326e-02],
#        [1.37685444e-02],
#        [1.10741665e-01],
#        [6.90814547e-01],
#        [4.17342561e-02],
#        [5.43320770e-01],
#        [5.13749606e-02],
#        [3.22861914e-01],
#        [1.72687473e-02],
#        [6.24942940e-01],
#        [2.62392422e-01],
#        [3.09765226e-02],
#        [6.47097586e-01],
#        [7.68175095e-02],
#        [6.41097445e-02],
#        [3.05768168e-01],
#        [2.06255403e-01],
#        [1.43387683e-02],
#        [3.22800312e-01],
#        [2.12362442e-01],
#        [8.67250095e-02],
#        [2.41619303e-04],
#        [1.93064641e-01],
#        [1.26688581e-01],
#        [1.35742097e-01],
#        [1.73045797e-02],
#        [1.22536253e-01],
#        [1.19427329e-01],
#        [2.59222139e-01],
#        [3.66888574e-01],
#        [1.89794241e-01],
#        [6.38851903e-02],
#        [4.16554918e-01],
#        [1.58212555e-01],
#        [2.06721626e-02],
#        [8.26338624e-03],
#        [1.62205946e-02],
#        [6.86871311e-02],
#        [5.34664642e-01],
#        [5.01893770e-02],
#        [3.15360998e-01],
#        [7.40234491e-01],
#        [1.18089750e-01],
#        [6.58324212e-03],
#        [3.86464768e-01],
#        [1.10158353e-01],
#        [1.59123288e-01],
#        [1.80205484e-02],
#        [1.01752404e-02],
#        [3.88954922e-02],
#        [1.78965888e-01],
#        [2.21838897e-01],
#        [1.05644307e-01],
#        [9.63595104e-03],
#        [2.24101908e-01],
#        [1.60670632e-01],
#        [1.57917464e-01],
#        [7.30737312e-02],
#        [3.85616098e-02],
#        [3.36040828e-02],
#        [2.83398336e-02],
#        [1.81265373e-02],
#        [5.84541851e-01],
#        [1.36034721e-01],
#        [9.59643632e-02],
#        [2.01891714e-01],
#        [5.96817515e-01],
#        [1.49087327e-01],
#        [9.35956645e-02],
#        [6.37083299e-01],
#        [5.69194796e-02],
#        [1.99437719e-01],
#        [2.74649023e-01],
#        [7.11721676e-01],
#        [2.92432601e-01],
#        [4.39307824e-04],
#        [1.14317192e-01],
#        [6.37624692e-02],
#        [2.12773646e-01],
#        [3.53127325e-01],
#        [2.73547288e-01],
#        [1.18678447e-01],
#        [1.45325146e-01],
#        [3.46481412e-02],
#        [1.06431205e-01],
#        [1.88787781e-01],
#        [2.69951865e-01],
#        [5.94150857e-01],
#        [1.30277358e-01],
#        [1.60315651e-01],
#        [4.13673397e-01],
#        [1.11644954e-01],
#        [1.39579134e-01],
#        [6.38087956e-01],
#        [1.88226507e-01],
#        [6.05367700e-01],
#        [3.97408639e-01],
#        [1.69452832e-01],
#        [3.99112178e-01],
#        [5.58087024e-01],
#        [1.83680084e-01],
#        [2.01536949e-01],
#        [2.31295353e-01],
#        [2.24417749e-02],
#        [1.10214718e-01],
#        [3.29608060e-01],
#        [1.19465542e-01],
#        [5.25676122e-02],
#        [1.88802399e-01],
#        [1.15029806e-02],
#        [6.80249075e-02],
#        [2.90964337e-01],
#        [6.16971979e-01],
#        [1.91668103e-01],
#        [6.80536696e-02],
#        [1.71707557e-01],
#        [1.68184332e-01],
#        [3.13241311e-01],
#        [7.99208157e-02],
#        [2.10798321e-03],
#        [1.36999078e-01],
#        [5.06699212e-02],
#        [2.98110322e-01],
#        [1.47633713e-01],
#        [2.10086022e-01],
#        [6.55869315e-01],
#        [7.98117063e-03],
#        [5.85932921e-01],
#        [2.86024192e-01],
#        [1.64942452e-01],
#        [3.62575399e-02],
#        [1.22004014e-01],
#        [4.20755265e-02],
#        [9.74697954e-02],
#        [2.61369673e-01],
#        [1.57311410e-01],
#        [6.93768317e-01],
#        [5.86411443e-02],
#        [3.49947298e-01],
#        [8.08359135e-02],
#        [1.41038334e-01],
#        [8.10808178e-03],
#        [5.80116658e-01],
#        [5.37246894e-01],
#        [1.39635087e-01],
#        [1.83568572e-01],
#        [2.74688997e-02],
#        [3.73732882e-01],
#        [1.75632441e-01],
#        [2.42845924e-02],
#        [3.12093651e-02],
#        [8.84747003e-02],
#        [1.27376030e-01],
#        [1.09573181e-01],
#        [2.05579523e-01],
#        [6.45566535e-03],
#        [2.21338837e-01],
#        [1.38081319e-02],
#        [7.96583276e-02],
#        [2.05153684e-01],
#        [3.62514815e-02],
#        [1.26969331e-02],
#        [8.21550572e-01],
#        [1.23121613e-01],
#        [1.71122355e-01],
#        [1.03779635e-01],
#        [1.68435748e-01],
#        [1.63465562e-01],
#        [5.75325168e-01],
#        [1.25562113e-01],
#        [1.51312959e-01],
#        [3.40633078e-01],
#        [9.63862053e-02],
#        [4.12217111e-02],
#        [1.80837821e-02],
#        [8.48183949e-02],
#        [1.00874269e-01],
#        [8.83007562e-02],
#        [1.45934225e-01],
#        [4.39572826e-02],
#        [1.74153295e-01],
#        [8.38276880e-02],
#        [1.58843284e-01],
#        [1.48463805e-01],
#        [1.43966009e-01],
#        [1.17096782e-01],
#        [5.74826104e-01],
#        [1.14186690e-02],
#        [6.54486636e-01],
#        [2.50197922e-01],
#        [4.14951634e-01],
#        [2.84932691e-01],
#        [7.74240391e-02],
#        [6.32076473e-01],
#        [2.07470807e-01],
#        [5.35531486e-01],
#        [4.57480965e-02],
#        [7.88354667e-03],
#        [9.71709242e-02],
#        [5.93103616e-02],
#        [1.65977110e-01],
#        [5.29834933e-02],
#        [2.29794710e-01],
#        [2.84478090e-02],
#        [3.54113090e-01],
#        [7.19662890e-02],
#        [1.37316116e-01],
#        [2.04566455e-01],
#        [3.20866175e-01],
#        [3.13807961e-01],
#        [1.34523315e-01],
#        [7.11591019e-01],
#        [6.81452155e-01],
#        [4.11895228e-01],
#        [2.59077111e-01],
#        [3.21001955e-01],
#        [5.99552089e-02],
#        [4.36703670e-02],
#        [3.27245238e-02],
#        [1.56751553e-01],
#        [1.54440313e-01],
#        [1.88692032e-02],
#        [7.65896399e-02],
#        [4.18219707e-01],
#        [6.27263402e-01],
#        [1.85467865e-01],
#        [3.58290761e-01],
#        [2.11856833e-01],
#        [7.25910361e-01],
#        [4.80810546e-02],
#        [5.74048308e-02],
#        [1.48998012e-02],
#        [1.74345095e-01],
#        [6.20310438e-01],
#        [4.44201717e-01],
#        [8.16686701e-02],
#        [3.44460408e-02],
#        [1.16854941e-01],
#        [1.64184970e-02],
#        [4.64554504e-02],
#        [5.04597638e-01],
#        [7.61431397e-01],
#        [7.30541797e-01],
#        [1.61025584e-02],
#        [1.64806214e-02],
#        [9.35580251e-03],
#        [1.11128597e-01],
#        [1.54354498e-01],
#        [1.54417984e-01],
#        [9.37055704e-03],
#        [6.78892619e-02],
#        [1.81995116e-01],
#        [5.81091639e-02],
#        [5.68970003e-02],
#        [1.43447588e-02],
#        [3.08047504e-01],
#        [7.64434258e-02],
#        [1.32374102e-01],
#        [2.03079421e-01],
#        [7.74951197e-02],
#        [2.60933556e-01],
#        [1.41570127e-01],
#        [6.82496645e-02],
#        [2.53355887e-02],
#        [1.18038719e-01],
#        [1.66780880e-02],
#        [1.72752917e-01],
#        [1.37288014e-01],
#        [1.39681230e-01],
#        [6.51688946e-01],
#        [1.05672605e-01],
#        [3.35556956e-01],
#        [1.72266258e-02],
#        [1.40282343e-01],
#        [2.14989130e-01],
#        [1.24013486e-01],
#        [4.42895936e-01],
#        [2.96859538e-01],
#        [6.60132402e-02],
#        [3.03268811e-02],
#        [1.77925229e-01],
#        [1.44472640e-02],
#        [2.78577171e-02],
#        [2.84289498e-02],
#        [1.59041386e-01],
#        [1.31518644e-01],
#        [5.45006209e-02],
#        [2.03760969e-01],
#        [2.63443679e-01],
#        [5.16399747e-02],
#        [1.11796844e-01],
#        [4.47248732e-01],
#        [7.62400065e-01],
#        [7.98605183e-03],
#        [4.03367432e-01],
#        [8.10006579e-02],
#        [1.91396770e-01],
#        [1.96909363e-01],
#        [6.71009437e-02],
#        [2.51610757e-01],
#        [8.13980957e-03],
#        [3.62105192e-01],
#        [1.02401246e-01],
#        [2.56995285e-02],
#        [9.97612505e-02],
#        [2.04770871e-02],
#        [9.05845224e-02],
#        [1.21090281e-02],
#        [1.22941574e-01],
#        [3.50264218e-01],
#        [5.70094452e-01],
#        [1.38534950e-01],
#        [6.16227152e-01],
#        [5.77000983e-01],
#        [1.39325771e-01],
#        [1.56490571e-02],
#        [7.75414081e-02],
#        [1.34397701e-01],
#        [5.23213528e-02],
#        [1.12527593e-02],
#        [3.66134648e-01],
#        [1.33741301e-01],
#        [2.03661126e-01],
#        [3.33010027e-01],
#        [3.24837583e-01],
#        [9.61809731e-02],
#        [1.34801467e-01],
#        [1.62139368e-02],
#        [6.92142478e-02],
#        [9.02508794e-02],
#        [8.82316293e-03]])

# %%
# Importer les fonctions r2_score, mean_squared_error et mean_absolute_error du sous-module sklearn.metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Calculer et afficher les mesures de performance du modèle
# Le coefficient de détermination R2 mesure la proportion de la variance de la variable cible qui est expliquée par le modèle
# L'erreur quadratique moyenne MSE mesure la moyenne des carrés des erreurs entre les valeurs réelles et les valeurs prédites
# L'erreur absolue moyenne MAE mesure la moyenne des valeurs absolues des erreurs entre les valeurs réelles et les valeurs prédites
R2 = r2_score(y_test_orig, y_predict_orig)
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
print(R2, MSE, MAE)
# Out:
# -8.451801317721497e-05 143608722.73004648 9161.591397525186
